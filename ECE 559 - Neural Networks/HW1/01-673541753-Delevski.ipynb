# %%
from matplotlib import pyplot as plt
import numpy as np
np.random.seed(1)

# %%
###### FUNCTIONS #######

def get_weights_and_bias():
    w0 = (2/4) * np.random.random_sample(1) - (1/4)
    w1 = 2 * np.random.random_sample(1) - 1
    w2 = 2 * np.random.random_sample(1) - 1
    return w0, w1, w2

def get_vectors_s(n):
    S = 2 * np.random.random_sample((n,2)) - 1 
    return S

# %%
S = get_vectors_s(100)

# %%
w0i, w1i, w2i = get_weights_and_bias()
weights_i = np.array((w0i, w1i, w2i))
print(weights_i)
# Out:
# [[0.22508806]
#  [0.11330638]
#  [0.8312127 ]]

# %%
S0 = np.empty(shape=(0,2),dtype='object') 
S1 = np.empty(shape=(0,2),dtype='object')
labels = np.empty(shape=(0, 1),dtype='int')

for vector in S:
    if np.dot([1, vector[0], vector[1]], weights_i) < 0:
        S0 = np.vstack((S0, vector))
        labels = np.vstack((labels, 0))
    elif np.dot([1, vector[0], vector[1]], weights_i) >= 0:
        S1 = np.vstack((S1, vector)) 
        labels = np.vstack((labels, 1)) 

plt.scatter(([vector[0] for vector in S0]), ([vector[1] for vector in S0]), marker='o', label='S0')
plt.scatter(([vector[0] for vector in S1]), ([vector[1] for vector in S1]), marker='x', label='S1')
x = np.linspace(-1,1)
y = (-w0i-w1i*x)/w2i
plt.plot(x, y, '-r', label='Boundary')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show()

# %%
w0, w1, w2 = get_weights_and_bias()
weights = np.array((w0, w1, w2))
print(weights)
# Out:
# [[ 0.0707831 ]
#  [-0.21998457]
#  [-0.02801867]]

# %%
class Perceptron(object):

    def __init__(self, num_of_inputs, weights, learning_rate):
        self.num_of_inputs = num_of_inputs
        self.learning_rate = learning_rate
        self.weights = weights
        self.epochs = 0
        self.misclassified = 0
        self.count = 0
        self.misclassified_list = []

    def predict(self, inputs):
        result = np.dot([1, inputs[0], inputs[1]], self.weights)
        if result >= 0:
            prediction = np.array([1])
        else:
            prediction = np.array([0])
        return prediction 

    def train(self, training_inputs, labels):
        self.misclassified = 0
        for label, inputs in zip(labels, training_inputs):
            self.count += 1
            prediction = self.predict(inputs)
            print(f'Input: {inputs}, Label: {label}, Prediction: {prediction}, Count: {self.count}')
            if prediction > label:
                self.weights[0] -= self.learning_rate * 1
                self.weights[1] -= self.learning_rate * inputs[0]
                self.weights[2] -= self.learning_rate * inputs[1]
                self.misclassified += 1
            elif prediction < label:
                self.weights[0] += self.learning_rate * 1
                self.weights[1] += self.learning_rate * inputs[0]
                self.weights[2] += self.learning_rate * inputs[1]
                self.misclassified += 1
            else:
                print('Prediction = Label') 
            print('Misclassified: ', self.misclassified)
        self.misclassified_list.append(self.misclassified)
        self.epochs += 1
        print(f'Weights: {self.weights}, Epochs: {self.epochs}')

# %%
perceptron = Perceptron(2, weights, 0.1)

# %%
perceptron.train(S, labels)
print(perceptron.misclassified)
while (perceptron.misclassified != 0):
    perceptron.train(S, labels)
print(perceptron.misclassified_list)
# Out:
# Input: [-0.16595599  0.44064899], Label: [1], Prediction: [1], Count: 1
# Prediction = Label
# Misclassified:  0
# Input: [-0.99977125 -0.39533485], Label: [0], Prediction: [1], Count: 2
# Misclassified:  1
# Input: [-0.70648822 -0.81532281], Label: [0], Prediction: [1], Count: 3
# Misclassified:  2
# Input: [-0.62747958 -0.30887855], Label: [0], Prediction: [0], Count: 4
# Prediction = Label
# Misclassified:  2
# Input: [-0.20646505  0.07763347], Label: [1], Prediction: [0], Count: 5
# Misclassified:  3
# Input: [-0.16161097  0.370439  ], Label: [1], Prediction: [1], Count: 6
# Prediction = Label
# Misclassified:  3
# Input: [-0.5910955   0.75623487], Label: [1], Prediction: [1], Count: 7
# Prediction = Label
# Misclassified:  3
# Input: [-0.94522481  0.34093502], Label: [1], Prediction: [1], Count: 8
# Prediction = Label
# Misclassified:  3
# Input: [-0.1653904   0.11737966], Label: [1], Prediction: [0], Count: 9
# Misclassified:  4
# Input: [-0.71922612 -0.60379702], Label: [0], Prediction: [1], Count: 10
# Misclassified:  5
# Input: [0.60148914 0.93652315], Label: [1], Prediction: [1], Count: 11
# Prediction = Label
# Misclassified:  5
# Input: [-0.37315164  0.38464523], Label: [1], Prediction: [1], Count: 12
# Prediction = Label
# Misclassified:  5
# Input: [0.7527783  0.78921333], Label: [1], Prediction: [1], Count: 13
# Prediction = Label
# Misclassified:  5
# Input: [-0.82991158 -0.92189043], Label: [0], Prediction: [0], Count: 14
# Prediction = Label
# Misclassified:  5
# Input: [-0.66033916  0.75628501], Label: [1], Prediction: [1], Count: 15
# Prediction = Label
# Misclassified:  5
# Input: [-0.80330633 -0.15778475], Label: [1], Prediction: [0], Count: 16
# Misclassified:  6
# Input: [0.91577906 0.06633057], Label: [1], Prediction: [0], Count: 17
# Misclassified:  7
# Input: [ 0.38375423 -0.36896874], Label: [0], Prediction: [1], Count: 18
# Misclassified:  8
# Input: [0.37300186 0.66925134], Label: [1], Prediction: [1], Count: 19
# Prediction = Label
# Misclassified:  8
# Input: [-0.96342345  0.50028863], Label: [1], Prediction: [1], Count: 20
# Prediction = Label
# Misclassified:  8
# Input: [0.97772218 0.49633131], Label: [1], Prediction: [1], Count: 21
# Prediction = Label
# Misclassified:  8
# Input: [-0.43911202  0.57855866], Label: [1], Prediction: [1], Count: 22
# Prediction = Label
# Misclassified:  8
# Input: [-0.79354799 -0.10421295], Label: [1], Prediction: [1], Count: 23
# Prediction = Label
# Misclassified:  8
# Input: [ 0.81719101 -0.4127717 ], Label: [0], Prediction: [0], Count: 24
# Prediction = Label
# Misclassified:  8
# Input: [-0.42444932 -0.73994286], Label: [0], Prediction: [0], Count: 25
# Prediction = Label
# Misclassified:  8
# Input: [-0.96126608  0.35767107], Label: [1], Prediction: [1], Count: 26
# Prediction = Label
# Misclassified:  8
# Input: [-0.57674377 -0.46890668], Label: [0], Prediction: [1], Count: 27
# Misclassified:  9
# Input: [-0.01685368 -0.89327491], Label: [0], Prediction: [0], Count: 28
# Prediction = Label
# Misclassified:  9
# Input: [ 0.14823521 -0.70654285], Label: [0], Prediction: [0], Count: 29
# Prediction = Label
# Misclassified:  9
# Input: [0.17861107 0.39951672], Label: [1], Prediction: [1], Count: 30
# Prediction = Label
# Misclassified:  9
# Input: [-0.79533114 -0.17188802], Label: [0], Prediction: [0], Count: 31
# Prediction = Label
# Misclassified:  9
# Input: [ 0.38880032 -0.17164146], Label: [1], Prediction: [0], Count: 32
# Misclassified:  10
# Input: [-0.90009308  0.07179281], Label: [1], Prediction: [1], Count: 33
# Prediction = Label
# Misclassified:  10
# Input: [0.32758929 0.02977822], Label: [1], Prediction: [1], Count: 34
# Prediction = Label
# Misclassified:  10
# Input: [0.88918951 0.17311008], Label: [1], Prediction: [1], Count: 35
# Prediction = Label
# Misclassified:  10
# Input: [ 0.80680383 -0.72505059], Label: [0], Prediction: [0], Count: 36
# Prediction = Label
# Misclassified:  10
# Input: [-0.72144731  0.61478258], Label: [1], Prediction: [1], Count: 37
# Prediction = Label
# Misclassified:  10
# Input: [-0.20464633 -0.66929161], Label: [0], Prediction: [0], Count: 38
# Prediction = Label
# Misclassified:  10
# Input: [ 0.85501716 -0.30446828], Label: [1], Prediction: [1], Count: 39
# Prediction = Label
# Misclassified:  10
# Input: [0.50162421 0.45199597], Label: [1], Prediction: [1], Count: 40
# Prediction = Label
# Misclassified:  10
# Input: [0.76661218 0.24734441], Label: [1], Prediction: [1], Count: 41
# Prediction = Label
# Misclassified:  10
# Input: [ 0.50188487 -0.30220332], Label: [1], Prediction: [1], Count: 42
# Prediction = Label
# Misclassified:  10
# Input: [-0.46014422  0.79177244], Label: [1], Prediction: [1], Count: 43
# Prediction = Label
# Misclassified:  10
# Input: [-0.14381762  0.92968009], Label: [1], Prediction: [1], Count: 44
# Prediction = Label
# Misclassified:  10
# Input: [0.326883   0.24339144], Label: [1], Prediction: [1], Count: 45
# Prediction = Label
# Misclassified:  10
# Input: [-0.77050805  0.89897852], Label: [1], Prediction: [1], Count: 46
# Prediction = Label
# Misclassified:  10
# Input: [-0.10017573  0.15677923], Label: [1], Prediction: [1], Count: 47
# Prediction = Label
# Misclassified:  10
# Input: [-0.18372639 -0.52594604], Label: [0], Prediction: [0], Count: 48
# Prediction = Label
# Misclassified:  10
# Input: [0.80675904 0.14735897], Label: [1], Prediction: [1], Count: 49
# Prediction = Label
# Misclassified:  10
# Input: [-0.99425935  0.23428983], Label: [1], Prediction: [1], Count: 50
# Prediction = Label
# Misclassified:  10
# Input: [-0.3467102  0.0541162], Label: [1], Prediction: [1], Count: 51
# Prediction = Label
# Misclassified:  10
# Input: [ 0.7718842  -0.28546048], Label: [1], Prediction: [1], Count: 52
# Prediction = Label
# Misclassified:  10
# Input: [0.8170703  0.24672023], Label: [1], Prediction: [1], Count: 53
# Prediction = Label
# Misclassified:  10
# Input: [-0.96835751  0.85887447], Label: [1], Prediction: [1], Count: 54
# Prediction = Label
# Misclassified:  10
# Input: [0.38179384 0.9946457 ], Label: [1], Prediction: [1], Count: 55
# Prediction = Label
# Misclassified:  10
# Input: [-0.65531898 -0.7257285 ], Label: [0], Prediction: [0], Count: 56
# Prediction = Label
# Misclassified:  10
# Input: [0.86519093 0.39363632], Label: [1], Prediction: [1], Count: 57
# Prediction = Label
# Misclassified:  10
# Input: [-0.86799965  0.51092611], Label: [1], Prediction: [1], Count: 58
# Prediction = Label
# Misclassified:  10
# Input: [0.50775238 0.84604907], Label: [1], Prediction: [1], Count: 59
# Prediction = Label
# Misclassified:  10
# Input: [ 0.42304952 -0.75145808], Label: [0], Prediction: [0], Count: 60
# Prediction = Label
# Misclassified:  10
# Input: [-0.96023973 -0.94757803], Label: [0], Prediction: [0], Count: 61
# Prediction = Label
# Misclassified:  10
# Input: [-0.94338702 -0.50757786], Label: [0], Prediction: [0], Count: 62
# Prediction = Label
# Misclassified:  10
# Input: [0.7200559  0.07766213], Label: [1], Prediction: [1], Count: 63
# Prediction = Label
# Misclassified:  10
# Input: [0.10564396 0.68406178], Label: [1], Prediction: [1], Count: 64
# Prediction = Label
# Misclassified:  10
# Input: [-0.75165337 -0.44163264], Label: [0], Prediction: [0], Count: 65
# Prediction = Label
# Misclassified:  10
# Input: [0.17151854 0.9391915 ], Label: [1], Prediction: [1], Count: 66
# Prediction = Label
# Misclassified:  10
# Input: [ 0.12206044 -0.96270542], Label: [0], Prediction: [0], Count: 67
# Prediction = Label
# Misclassified:  10
# Input: [ 0.60126535 -0.53405145], Label: [0], Prediction: [0], Count: 68
# Prediction = Label
# Misclassified:  10
# Input: [ 0.61421039 -0.22427871], Label: [1], Prediction: [1], Count: 69
# Prediction = Label
# Misclassified:  10
# Input: [0.72708371 0.49424329], Label: [1], Prediction: [1], Count: 70
# Prediction = Label
# Misclassified:  10
# Input: [ 0.11248047 -0.72708955], Label: [0], Prediction: [0], Count: 71
# Prediction = Label
# Misclassified:  10
# Input: [-0.88016462 -0.75731309], Label: [0], Prediction: [0], Count: 72
# Prediction = Label
# Misclassified:  10
# Input: [-0.91089624 -0.78501174], Label: [0], Prediction: [0], Count: 73
# Prediction = Label
# Misclassified:  10
# Input: [-0.54858132  0.42597796], Label: [1], Prediction: [1], Count: 74
# Prediction = Label
# Misclassified:  10
# Input: [ 0.11943396 -0.97488804], Label: [0], Prediction: [0], Count: 75
# Prediction = Label
# Misclassified:  10
# Input: [-0.85605144  0.93455266], Label: [1], Prediction: [1], Count: 76
# Prediction = Label
# Misclassified:  10
# Input: [ 0.13620092 -0.59341353], Label: [0], Prediction: [0], Count: 77
# Prediction = Label
# Misclassified:  10
# Input: [-0.49534851  0.48765171], Label: [1], Prediction: [1], Count: 78
# Prediction = Label
# Misclassified:  10
# Input: [-0.60914104  0.16271785], Label: [1], Prediction: [1], Count: 79
# Prediction = Label
# Misclassified:  10
# Input: [0.94003998 0.6936576 ], Label: [1], Prediction: [1], Count: 80
# Prediction = Label
# Misclassified:  10
# Input: [-0.52030448 -0.01246057], Label: [1], Prediction: [1], Count: 81
# Prediction = Label
# Misclassified:  10
# Input: [0.23991144 0.6579618 ], Label: [1], Prediction: [1], Count: 82
# Prediction = Label
# Misclassified:  10
# Input: [-0.68641721 -0.9628476 ], Label: [0], Prediction: [0], Count: 83
# Prediction = Label
# Misclassified:  10
# Input: [-0.85995571 -0.02730978], Label: [1], Prediction: [1], Count: 84
# Prediction = Label
# Misclassified:  10
# Input: [0.21265892 0.13770287], Label: [1], Prediction: [1], Count: 85
# Prediction = Label
# Misclassified:  10
# Input: [-0.36527518  0.97723231], Label: [1], Prediction: [1], Count: 86
# Prediction = Label
# Misclassified:  10
# Input: [ 0.15949044 -0.23971765], Label: [1], Prediction: [1], Count: 87
# Prediction = Label
# Misclassified:  10
# Input: [0.10189644 0.49066886], Label: [1], Prediction: [1], Count: 88
# Prediction = Label
# Misclassified:  10
# Input: [ 0.33846579 -0.47016088], Label: [0], Prediction: [0], Count: 89
# Prediction = Label
# Misclassified:  10
# Input: [-0.86733033 -0.2598316 ], Label: [0], Prediction: [0], Count: 90
# Prediction = Label
# Misclassified:  10
# Input: [ 0.25943501 -0.57965198], Label: [0], Prediction: [0], Count: 91
# Prediction = Label
# Misclassified:  10
# Input: [ 0.50551111 -0.86692704], Label: [0], Prediction: [0], Count: 92
# Prediction = Label
# Misclassified:  10
# Input: [-0.4793698   0.60950913], Label: [1], Prediction: [1], Count: 93
# Prediction = Label
# Misclassified:  10
# Input: [-0.61313143  0.27892176], Label: [1], Prediction: [1], Count: 94
# Prediction = Label
# Misclassified:  10
# Input: [0.04934062 0.84961594], Label: [1], Prediction: [1], Count: 95
# Prediction = Label
# Misclassified:  10
# Input: [-0.47340646 -0.86807782], Label: [0], Prediction: [0], Count: 96
# Prediction = Label
# Misclassified:  10
# Input: [0.47013193 0.54435606], Label: [1], Prediction: [1], Count: 97
# Prediction = Label
# Misclassified:  10
# Input: [0.81563171 0.86394414], Label: [1], Prediction: [1], Count: 98
# Prediction = Label
# Misclassified:  10
# Input: [-0.97209685 -0.53127583], Label: [0], Prediction: [0], Count: 99
# Prediction = Label
# Misclassified:  10
# Input: [0.23355671 0.89803264], Label: [1], Prediction: [1], Count: 100
# Prediction = Label
# Misclassified:  10
# Weights: [[0.0707831 ]
#  [0.0548047 ]
#  [0.23040609]], Epochs: 1
# 10
# Input: [-0.16595599  0.44064899], Label: [1], Prediction: [1], Count: 101
# Prediction = Label
# Misclassified:  0
# Input: [-0.99977125 -0.39533485], Label: [0], Prediction: [0], Count: 102
# Prediction = Label
# Misclassified:  0
# Input: [-0.70648822 -0.81532281], Label: [0], Prediction: [0], Count: 103
# Prediction = Label
# Misclassified:  0
# Input: [-0.62747958 -0.30887855], Label: [0], Prediction: [0], Count: 104
# Prediction = Label
# Misclassified:  0
# Input: [-0.20646505  0.07763347], Label: [1], Prediction: [1], Count: 105
# Prediction = Label
# Misclassified:  0
# Input: [-0.16161097  0.370439  ], Label: [1], Prediction: [1], Count: 106
# Prediction = Label
# Misclassified:  0
# Input: [-0.5910955   0.75623487], Label: [1], Prediction: [1], Count: 107
# Prediction = Label
# Misclassified:  0
# Input: [-0.94522481  0.34093502], Label: [1], Prediction: [1], Count: 108
# Prediction = Label
# Misclassified:  0
# Input: [-0.1653904   0.11737966], Label: [1], Prediction: [1], Count: 109
# Prediction = Label
# Misclassified:  0
# Input: [-0.71922612 -0.60379702], Label: [0], Prediction: [0], Count: 110
# Prediction = Label
# Misclassified:  0
# Input: [0.60148914 0.93652315], Label: [1], Prediction: [1], Count: 111
# Prediction = Label
# Misclassified:  0
# Input: [-0.37315164  0.38464523], Label: [1], Prediction: [1], Count: 112
# Prediction = Label
# Misclassified:  0
# Input: [0.7527783  0.78921333], Label: [1], Prediction: [1], Count: 113
# Prediction = Label
# Misclassified:  0
# Input: [-0.82991158 -0.92189043], Label: [0], Prediction: [0], Count: 114
# Prediction = Label
# Misclassified:  0
# Input: [-0.66033916  0.75628501], Label: [1], Prediction: [1], Count: 115
# Prediction = Label
# Misclassified:  0
# Input: [-0.80330633 -0.15778475], Label: [1], Prediction: [0], Count: 116
# Misclassified:  1
# Input: [0.91577906 0.06633057], Label: [1], Prediction: [1], Count: 117
# Prediction = Label
# Misclassified:  1
# Input: [ 0.38375423 -0.36896874], Label: [0], Prediction: [1], Count: 118
# Misclassified:  2
# Input: [0.37300186 0.66925134], Label: [1], Prediction: [1], Count: 119
# Prediction = Label
# Misclassified:  2
# Input: [-0.96342345  0.50028863], Label: [1], Prediction: [1], Count: 120
# Prediction = Label
# Misclassified:  2
# Input: [0.97772218 0.49633131], Label: [1], Prediction: [1], Count: 121
# Prediction = Label
# Misclassified:  2
# Input: [-0.43911202  0.57855866], Label: [1], Prediction: [1], Count: 122
# Prediction = Label
# Misclassified:  2
# Input: [-0.79354799 -0.10421295], Label: [1], Prediction: [1], Count: 123
# Prediction = Label
# Misclassified:  2
# Input: [ 0.81719101 -0.4127717 ], Label: [0], Prediction: [0], Count: 124
# Prediction = Label
# Misclassified:  2
# Input: [-0.42444932 -0.73994286], Label: [0], Prediction: [0], Count: 125
# Prediction = Label
# Misclassified:  2
# Input: [-0.96126608  0.35767107], Label: [1], Prediction: [1], Count: 126
# Prediction = Label
# Misclassified:  2
# Input: [-0.57674377 -0.46890668], Label: [0], Prediction: [0], Count: 127
# Prediction = Label
# Misclassified:  2
# Input: [-0.01685368 -0.89327491], Label: [0], Prediction: [0], Count: 128
# Prediction = Label
# Misclassified:  2
# Input: [ 0.14823521 -0.70654285], Label: [0], Prediction: [0], Count: 129
# Prediction = Label
# Misclassified:  2
# Input: [0.17861107 0.39951672], Label: [1], Prediction: [1], Count: 130
# Prediction = Label
# Misclassified:  2
# Input: [-0.79533114 -0.17188802], Label: [0], Prediction: [1], Count: 131
# Misclassified:  3
# Input: [ 0.38880032 -0.17164146], Label: [1], Prediction: [0], Count: 132
# Misclassified:  4
# Input: [-0.90009308  0.07179281], Label: [1], Prediction: [1], Count: 133
# Prediction = Label
# Misclassified:  4
# Input: [0.32758929 0.02977822], Label: [1], Prediction: [1], Count: 134
# Prediction = Label
# Misclassified:  4
# Input: [0.88918951 0.17311008], Label: [1], Prediction: [1], Count: 135
# Prediction = Label
# Misclassified:  4
# Input: [ 0.80680383 -0.72505059], Label: [0], Prediction: [0], Count: 136
# Prediction = Label
# Misclassified:  4
# Input: [-0.72144731  0.61478258], Label: [1], Prediction: [1], Count: 137
# Prediction = Label
# Misclassified:  4
# Input: [-0.20464633 -0.66929161], Label: [0], Prediction: [0], Count: 138
# Prediction = Label
# Misclassified:  4
# Input: [ 0.85501716 -0.30446828], Label: [1], Prediction: [1], Count: 139
# Prediction = Label
# Misclassified:  4
# Input: [0.50162421 0.45199597], Label: [1], Prediction: [1], Count: 140
# Prediction = Label
# Misclassified:  4
# Input: [0.76661218 0.24734441], Label: [1], Prediction: [1], Count: 141
# Prediction = Label
# Misclassified:  4
# Input: [ 0.50188487 -0.30220332], Label: [1], Prediction: [1], Count: 142
# Prediction = Label
# Misclassified:  4
# Input: [-0.46014422  0.79177244], Label: [1], Prediction: [1], Count: 143
# Prediction = Label
# Misclassified:  4
# Input: [-0.14381762  0.92968009], Label: [1], Prediction: [1], Count: 144
# Prediction = Label
# Misclassified:  4
# Input: [0.326883   0.24339144], Label: [1], Prediction: [1], Count: 145
# Prediction = Label
# Misclassified:  4
# Input: [-0.77050805  0.89897852], Label: [1], Prediction: [1], Count: 146
# Prediction = Label
# Misclassified:  4
# Input: [-0.10017573  0.15677923], Label: [1], Prediction: [1], Count: 147
# Prediction = Label
# Misclassified:  4
# Input: [-0.18372639 -0.52594604], Label: [0], Prediction: [0], Count: 148
# Prediction = Label
# Misclassified:  4
# Input: [0.80675904 0.14735897], Label: [1], Prediction: [1], Count: 149
# Prediction = Label
# Misclassified:  4
# Input: [-0.99425935  0.23428983], Label: [1], Prediction: [1], Count: 150
# Prediction = Label
# Misclassified:  4
# Input: [-0.3467102  0.0541162], Label: [1], Prediction: [1], Count: 151
# Prediction = Label
# Misclassified:  4
# Input: [ 0.7718842  -0.28546048], Label: [1], Prediction: [1], Count: 152
# Prediction = Label
# Misclassified:  4
# Input: [0.8170703  0.24672023], Label: [1], Prediction: [1], Count: 153
# Prediction = Label
# Misclassified:  4
# Input: [-0.96835751  0.85887447], Label: [1], Prediction: [1], Count: 154
# Prediction = Label
# Misclassified:  4
# Input: [0.38179384 0.9946457 ], Label: [1], Prediction: [1], Count: 155
# Prediction = Label
# Misclassified:  4
# Input: [-0.65531898 -0.7257285 ], Label: [0], Prediction: [0], Count: 156
# Prediction = Label
# Misclassified:  4
# Input: [0.86519093 0.39363632], Label: [1], Prediction: [1], Count: 157
# Prediction = Label
# Misclassified:  4
# Input: [-0.86799965  0.51092611], Label: [1], Prediction: [1], Count: 158
# Prediction = Label
# Misclassified:  4
# Input: [0.50775238 0.84604907], Label: [1], Prediction: [1], Count: 159
# Prediction = Label
# Misclassified:  4
# Input: [ 0.42304952 -0.75145808], Label: [0], Prediction: [0], Count: 160
# Prediction = Label
# Misclassified:  4
# Input: [-0.96023973 -0.94757803], Label: [0], Prediction: [0], Count: 161
# Prediction = Label
# Misclassified:  4
# Input: [-0.94338702 -0.50757786], Label: [0], Prediction: [0], Count: 162
# Prediction = Label
# Misclassified:  4
# Input: [0.7200559  0.07766213], Label: [1], Prediction: [1], Count: 163
# Prediction = Label
# Misclassified:  4
# Input: [0.10564396 0.68406178], Label: [1], Prediction: [1], Count: 164
# Prediction = Label
# Misclassified:  4
# Input: [-0.75165337 -0.44163264], Label: [0], Prediction: [0], Count: 165
# Prediction = Label
# Misclassified:  4
# Input: [0.17151854 0.9391915 ], Label: [1], Prediction: [1], Count: 166
# Prediction = Label
# Misclassified:  4
# Input: [ 0.12206044 -0.96270542], Label: [0], Prediction: [0], Count: 167
# Prediction = Label
# Misclassified:  4
# Input: [ 0.60126535 -0.53405145], Label: [0], Prediction: [0], Count: 168
# Prediction = Label
# Misclassified:  4
# Input: [ 0.61421039 -0.22427871], Label: [1], Prediction: [1], Count: 169
# Prediction = Label
# Misclassified:  4
# Input: [0.72708371 0.49424329], Label: [1], Prediction: [1], Count: 170
# Prediction = Label
# Misclassified:  4
# Input: [ 0.11248047 -0.72708955], Label: [0], Prediction: [0], Count: 171
# Prediction = Label
# Misclassified:  4
# Input: [-0.88016462 -0.75731309], Label: [0], Prediction: [0], Count: 172
# Prediction = Label
# Misclassified:  4
# Input: [-0.91089624 -0.78501174], Label: [0], Prediction: [0], Count: 173
# Prediction = Label
# Misclassified:  4
# Input: [-0.54858132  0.42597796], Label: [1], Prediction: [1], Count: 174
# Prediction = Label
# Misclassified:  4
# Input: [ 0.11943396 -0.97488804], Label: [0], Prediction: [0], Count: 175
# Prediction = Label
# Misclassified:  4
# Input: [-0.85605144  0.93455266], Label: [1], Prediction: [1], Count: 176
# Prediction = Label
# Misclassified:  4
# Input: [ 0.13620092 -0.59341353], Label: [0], Prediction: [0], Count: 177
# Prediction = Label
# Misclassified:  4
# Input: [-0.49534851  0.48765171], Label: [1], Prediction: [1], Count: 178
# Prediction = Label
# Misclassified:  4
# Input: [-0.60914104  0.16271785], Label: [1], Prediction: [1], Count: 179
# Prediction = Label
# Misclassified:  4
# Input: [0.94003998 0.6936576 ], Label: [1], Prediction: [1], Count: 180
# Prediction = Label
# Misclassified:  4
# Input: [-0.52030448 -0.01246057], Label: [1], Prediction: [1], Count: 181
# Prediction = Label
# Misclassified:  4
# Input: [0.23991144 0.6579618 ], Label: [1], Prediction: [1], Count: 182
# Prediction = Label
# Misclassified:  4
# Input: [-0.68641721 -0.9628476 ], Label: [0], Prediction: [0], Count: 183
# Prediction = Label
# Misclassified:  4
# Input: [-0.85995571 -0.02730978], Label: [1], Prediction: [1], Count: 184
# Prediction = Label
# Misclassified:  4
# Input: [0.21265892 0.13770287], Label: [1], Prediction: [1], Count: 185
# Prediction = Label
# Misclassified:  4
# Input: [-0.36527518  0.97723231], Label: [1], Prediction: [1], Count: 186
# Prediction = Label
# Misclassified:  4
# Input: [ 0.15949044 -0.23971765], Label: [1], Prediction: [1], Count: 187
# Prediction = Label
# Misclassified:  4
# Input: [0.10189644 0.49066886], Label: [1], Prediction: [1], Count: 188
# Prediction = Label
# Misclassified:  4
# Input: [ 0.33846579 -0.47016088], Label: [0], Prediction: [0], Count: 189
# Prediction = Label
# Misclassified:  4
# Input: [-0.86733033 -0.2598316 ], Label: [0], Prediction: [0], Count: 190
# Prediction = Label
# Misclassified:  4
# Input: [ 0.25943501 -0.57965198], Label: [0], Prediction: [0], Count: 191
# Prediction = Label
# Misclassified:  4
# Input: [ 0.50551111 -0.86692704], Label: [0], Prediction: [0], Count: 192
# Prediction = Label
# Misclassified:  4
# Input: [-0.4793698   0.60950913], Label: [1], Prediction: [1], Count: 193
# Prediction = Label
# Misclassified:  4
# Input: [-0.61313143  0.27892176], Label: [1], Prediction: [1], Count: 194
# Prediction = Label
# Misclassified:  4
# Input: [0.04934062 0.84961594], Label: [1], Prediction: [1], Count: 195
# Prediction = Label
# Misclassified:  4
# Input: [-0.47340646 -0.86807782], Label: [0], Prediction: [0], Count: 196
# Prediction = Label
# Misclassified:  4
# Input: [0.47013193 0.54435606], Label: [1], Prediction: [1], Count: 197
# Prediction = Label
# Misclassified:  4
# Input: [0.81563171 0.86394414], Label: [1], Prediction: [1], Count: 198
# Prediction = Label
# Misclassified:  4
# Input: [-0.97209685 -0.53127583], Label: [0], Prediction: [0], Count: 199
# Prediction = Label
# Misclassified:  4
# Input: [0.23355671 0.89803264], Label: [1], Prediction: [1], Count: 200
# Prediction = Label
# Misclassified:  4
# Weights: [[0.0707831 ]
#  [0.05451179]
#  [0.25154915]], Epochs: 2
# Input: [-0.16595599  0.44064899], Label: [1], Prediction: [1], Count: 201
# Prediction = Label
# Misclassified:  0
# Input: [-0.99977125 -0.39533485], Label: [0], Prediction: [0], Count: 202
# Prediction = Label
# Misclassified:  0
# Input: [-0.70648822 -0.81532281], Label: [0], Prediction: [0], Count: 203
# Prediction = Label
# Misclassified:  0
# Input: [-0.62747958 -0.30887855], Label: [0], Prediction: [0], Count: 204
# Prediction = Label
# Misclassified:  0
# Input: [-0.20646505  0.07763347], Label: [1], Prediction: [1], Count: 205
# Prediction = Label
# Misclassified:  0
# Input: [-0.16161097  0.370439  ], Label: [1], Prediction: [1], Count: 206
# Prediction = Label
# Misclassified:  0
# Input: [-0.5910955   0.75623487], Label: [1], Prediction: [1], Count: 207
# Prediction = Label
# Misclassified:  0
# Input: [-0.94522481  0.34093502], Label: [1], Prediction: [1], Count: 208
# Prediction = Label
# Misclassified:  0
# Input: [-0.1653904   0.11737966], Label: [1], Prediction: [1], Count: 209
# Prediction = Label
# Misclassified:  0
# Input: [-0.71922612 -0.60379702], Label: [0], Prediction: [0], Count: 210
# Prediction = Label
# Misclassified:  0
# Input: [0.60148914 0.93652315], Label: [1], Prediction: [1], Count: 211
# Prediction = Label
# Misclassified:  0
# Input: [-0.37315164  0.38464523], Label: [1], Prediction: [1], Count: 212
# Prediction = Label
# Misclassified:  0
# Input: [0.7527783  0.78921333], Label: [1], Prediction: [1], Count: 213
# Prediction = Label
# Misclassified:  0
# Input: [-0.82991158 -0.92189043], Label: [0], Prediction: [0], Count: 214
# Prediction = Label
# Misclassified:  0
# Input: [-0.66033916  0.75628501], Label: [1], Prediction: [1], Count: 215
# Prediction = Label
# Misclassified:  0
# Input: [-0.80330633 -0.15778475], Label: [1], Prediction: [0], Count: 216
# Misclassified:  1
# Input: [0.91577906 0.06633057], Label: [1], Prediction: [1], Count: 217
# Prediction = Label
# Misclassified:  1
# Input: [ 0.38375423 -0.36896874], Label: [0], Prediction: [1], Count: 218
# Misclassified:  2
# Input: [0.37300186 0.66925134], Label: [1], Prediction: [1], Count: 219
# Prediction = Label
# Misclassified:  2
# Input: [-0.96342345  0.50028863], Label: [1], Prediction: [1], Count: 220
# Prediction = Label
# Misclassified:  2
# Input: [0.97772218 0.49633131], Label: [1], Prediction: [1], Count: 221
# Prediction = Label
# Misclassified:  2
# Input: [-0.43911202  0.57855866], Label: [1], Prediction: [1], Count: 222
# Prediction = Label
# Misclassified:  2
# Input: [-0.79354799 -0.10421295], Label: [1], Prediction: [1], Count: 223
# Prediction = Label
# Misclassified:  2
# Input: [ 0.81719101 -0.4127717 ], Label: [0], Prediction: [0], Count: 224
# Prediction = Label
# Misclassified:  2
# Input: [-0.42444932 -0.73994286], Label: [0], Prediction: [0], Count: 225
# Prediction = Label
# Misclassified:  2
# Input: [-0.96126608  0.35767107], Label: [1], Prediction: [1], Count: 226
# Prediction = Label
# Misclassified:  2
# Input: [-0.57674377 -0.46890668], Label: [0], Prediction: [0], Count: 227
# Prediction = Label
# Misclassified:  2
# Input: [-0.01685368 -0.89327491], Label: [0], Prediction: [0], Count: 228
# Prediction = Label
# Misclassified:  2
# Input: [ 0.14823521 -0.70654285], Label: [0], Prediction: [0], Count: 229
# Prediction = Label
# Misclassified:  2
# Input: [0.17861107 0.39951672], Label: [1], Prediction: [1], Count: 230
# Prediction = Label
# Misclassified:  2
# Input: [-0.79533114 -0.17188802], Label: [0], Prediction: [1], Count: 231
# Misclassified:  3
# Input: [ 0.38880032 -0.17164146], Label: [1], Prediction: [0], Count: 232
# Misclassified:  4
# Input: [-0.90009308  0.07179281], Label: [1], Prediction: [1], Count: 233
# Prediction = Label
# Misclassified:  4
# Input: [0.32758929 0.02977822], Label: [1], Prediction: [1], Count: 234
# Prediction = Label
# Misclassified:  4
# Input: [0.88918951 0.17311008], Label: [1], Prediction: [1], Count: 235
# Prediction = Label
# Misclassified:  4
# Input: [ 0.80680383 -0.72505059], Label: [0], Prediction: [0], Count: 236
# Prediction = Label
# Misclassified:  4
# Input: [-0.72144731  0.61478258], Label: [1], Prediction: [1], Count: 237
# Prediction = Label
# Misclassified:  4
# Input: [-0.20464633 -0.66929161], Label: [0], Prediction: [0], Count: 238
# Prediction = Label
# Misclassified:  4
# Input: [ 0.85501716 -0.30446828], Label: [1], Prediction: [1], Count: 239
# Prediction = Label
# Misclassified:  4
# Input: [0.50162421 0.45199597], Label: [1], Prediction: [1], Count: 240
# Prediction = Label
# Misclassified:  4
# Input: [0.76661218 0.24734441], Label: [1], Prediction: [1], Count: 241
# Prediction = Label
# Misclassified:  4
# Input: [ 0.50188487 -0.30220332], Label: [1], Prediction: [1], Count: 242
# Prediction = Label
# Misclassified:  4
# Input: [-0.46014422  0.79177244], Label: [1], Prediction: [1], Count: 243
# Prediction = Label
# Misclassified:  4
# Input: [-0.14381762  0.92968009], Label: [1], Prediction: [1], Count: 244
# Prediction = Label
# Misclassified:  4
# Input: [0.326883   0.24339144], Label: [1], Prediction: [1], Count: 245
# Prediction = Label
# Misclassified:  4
# Input: [-0.77050805  0.89897852], Label: [1], Prediction: [1], Count: 246
# Prediction = Label
# Misclassified:  4
# Input: [-0.10017573  0.15677923], Label: [1], Prediction: [1], Count: 247
# Prediction = Label
# Misclassified:  4
# Input: [-0.18372639 -0.52594604], Label: [0], Prediction: [0], Count: 248
# Prediction = Label
# Misclassified:  4
# Input: [0.80675904 0.14735897], Label: [1], Prediction: [1], Count: 249
# Prediction = Label
# Misclassified:  4
# Input: [-0.99425935  0.23428983], Label: [1], Prediction: [1], Count: 250
# Prediction = Label
# Misclassified:  4
# Input: [-0.3467102  0.0541162], Label: [1], Prediction: [1], Count: 251
# Prediction = Label
# Misclassified:  4
# Input: [ 0.7718842  -0.28546048], Label: [1], Prediction: [1], Count: 252
# Prediction = Label
# Misclassified:  4
# Input: [0.8170703  0.24672023], Label: [1], Prediction: [1], Count: 253
# Prediction = Label
# Misclassified:  4
# Input: [-0.96835751  0.85887447], Label: [1], Prediction: [1], Count: 254
# Prediction = Label
# Misclassified:  4
# Input: [0.38179384 0.9946457 ], Label: [1], Prediction: [1], Count: 255
# Prediction = Label
# Misclassified:  4
# Input: [-0.65531898 -0.7257285 ], Label: [0], Prediction: [0], Count: 256
# Prediction = Label
# Misclassified:  4
# Input: [0.86519093 0.39363632], Label: [1], Prediction: [1], Count: 257
# Prediction = Label
# Misclassified:  4
# Input: [-0.86799965  0.51092611], Label: [1], Prediction: [1], Count: 258
# Prediction = Label
# Misclassified:  4
# Input: [0.50775238 0.84604907], Label: [1], Prediction: [1], Count: 259
# Prediction = Label
# Misclassified:  4
# Input: [ 0.42304952 -0.75145808], Label: [0], Prediction: [0], Count: 260
# Prediction = Label
# Misclassified:  4
# Input: [-0.96023973 -0.94757803], Label: [0], Prediction: [0], Count: 261
# Prediction = Label
# Misclassified:  4
# Input: [-0.94338702 -0.50757786], Label: [0], Prediction: [0], Count: 262
# Prediction = Label
# Misclassified:  4
# Input: [0.7200559  0.07766213], Label: [1], Prediction: [1], Count: 263
# Prediction = Label
# Misclassified:  4
# Input: [0.10564396 0.68406178], Label: [1], Prediction: [1], Count: 264
# Prediction = Label
# Misclassified:  4
# Input: [-0.75165337 -0.44163264], Label: [0], Prediction: [0], Count: 265
# Prediction = Label
# Misclassified:  4
# Input: [0.17151854 0.9391915 ], Label: [1], Prediction: [1], Count: 266
# Prediction = Label
# Misclassified:  4
# Input: [ 0.12206044 -0.96270542], Label: [0], Prediction: [0], Count: 267
# Prediction = Label
# Misclassified:  4
# Input: [ 0.60126535 -0.53405145], Label: [0], Prediction: [0], Count: 268
# Prediction = Label
# Misclassified:  4
# Input: [ 0.61421039 -0.22427871], Label: [1], Prediction: [1], Count: 269
# Prediction = Label
# Misclassified:  4
# Input: [0.72708371 0.49424329], Label: [1], Prediction: [1], Count: 270
# Prediction = Label
# Misclassified:  4
# Input: [ 0.11248047 -0.72708955], Label: [0], Prediction: [0], Count: 271
# Prediction = Label
# Misclassified:  4
# Input: [-0.88016462 -0.75731309], Label: [0], Prediction: [0], Count: 272
# Prediction = Label
# Misclassified:  4
# Input: [-0.91089624 -0.78501174], Label: [0], Prediction: [0], Count: 273
# Prediction = Label
# Misclassified:  4
# Input: [-0.54858132  0.42597796], Label: [1], Prediction: [1], Count: 274
# Prediction = Label
# Misclassified:  4
# Input: [ 0.11943396 -0.97488804], Label: [0], Prediction: [0], Count: 275
# Prediction = Label
# Misclassified:  4
# Input: [-0.85605144  0.93455266], Label: [1], Prediction: [1], Count: 276
# Prediction = Label
# Misclassified:  4
# Input: [ 0.13620092 -0.59341353], Label: [0], Prediction: [0], Count: 277
# Prediction = Label
# Misclassified:  4
# Input: [-0.49534851  0.48765171], Label: [1], Prediction: [1], Count: 278
# Prediction = Label
# Misclassified:  4
# Input: [-0.60914104  0.16271785], Label: [1], Prediction: [1], Count: 279
# Prediction = Label
# Misclassified:  4
# Input: [0.94003998 0.6936576 ], Label: [1], Prediction: [1], Count: 280
# Prediction = Label
# Misclassified:  4
# Input: [-0.52030448 -0.01246057], Label: [1], Prediction: [1], Count: 281
# Prediction = Label
# Misclassified:  4
# Input: [0.23991144 0.6579618 ], Label: [1], Prediction: [1], Count: 282
# Prediction = Label
# Misclassified:  4
# Input: [-0.68641721 -0.9628476 ], Label: [0], Prediction: [0], Count: 283
# Prediction = Label
# Misclassified:  4
# Input: [-0.85995571 -0.02730978], Label: [1], Prediction: [1], Count: 284
# Prediction = Label
# Misclassified:  4
# Input: [0.21265892 0.13770287], Label: [1], Prediction: [1], Count: 285
# Prediction = Label
# Misclassified:  4
# Input: [-0.36527518  0.97723231], Label: [1], Prediction: [1], Count: 286
# Prediction = Label
# Misclassified:  4
# Input: [ 0.15949044 -0.23971765], Label: [1], Prediction: [1], Count: 287
# Prediction = Label
# Misclassified:  4
# Input: [0.10189644 0.49066886], Label: [1], Prediction: [1], Count: 288
# Prediction = Label
# Misclassified:  4
# Input: [ 0.33846579 -0.47016088], Label: [0], Prediction: [0], Count: 289
# Prediction = Label
# Misclassified:  4
# Input: [-0.86733033 -0.2598316 ], Label: [0], Prediction: [0], Count: 290
# Prediction = Label
# Misclassified:  4
# Input: [ 0.25943501 -0.57965198], Label: [0], Prediction: [0], Count: 291
# Prediction = Label
# Misclassified:  4
# Input: [ 0.50551111 -0.86692704], Label: [0], Prediction: [0], Count: 292
# Prediction = Label
# Misclassified:  4
# Input: [-0.4793698   0.60950913], Label: [1], Prediction: [1], Count: 293
# Prediction = Label
# Misclassified:  4
# Input: [-0.61313143  0.27892176], Label: [1], Prediction: [1], Count: 294
# Prediction = Label
# Misclassified:  4
# Input: [0.04934062 0.84961594], Label: [1], Prediction: [1], Count: 295
# Prediction = Label
# Misclassified:  4
# Input: [-0.47340646 -0.86807782], Label: [0], Prediction: [0], Count: 296
# Prediction = Label
# Misclassified:  4
# Input: [0.47013193 0.54435606], Label: [1], Prediction: [1], Count: 297
# Prediction = Label
# Misclassified:  4
# Input: [0.81563171 0.86394414], Label: [1], Prediction: [1], Count: 298
# Prediction = Label
# Misclassified:  4
# Input: [-0.97209685 -0.53127583], Label: [0], Prediction: [0], Count: 299
# Prediction = Label
# Misclassified:  4
# Input: [0.23355671 0.89803264], Label: [1], Prediction: [1], Count: 300
# Prediction = Label
# Misclassified:  4
# Weights: [[0.0707831 ]
#  [0.05421888]
#  [0.2726922 ]], Epochs: 3
# Input: [-0.16595599  0.44064899], Label: [1], Prediction: [1], Count: 301
# Prediction = Label
# Misclassified:  0
# Input: [-0.99977125 -0.39533485], Label: [0], Prediction: [0], Count: 302
# Prediction = Label
# Misclassified:  0
# Input: [-0.70648822 -0.81532281], Label: [0], Prediction: [0], Count: 303
# Prediction = Label
# Misclassified:  0
# Input: [-0.62747958 -0.30887855], Label: [0], Prediction: [0], Count: 304
# Prediction = Label
# Misclassified:  0
# Input: [-0.20646505  0.07763347], Label: [1], Prediction: [1], Count: 305
# Prediction = Label
# Misclassified:  0
# Input: [-0.16161097  0.370439  ], Label: [1], Prediction: [1], Count: 306
# Prediction = Label
# Misclassified:  0
# Input: [-0.5910955   0.75623487], Label: [1], Prediction: [1], Count: 307
# Prediction = Label
# Misclassified:  0
# Input: [-0.94522481  0.34093502], Label: [1], Prediction: [1], Count: 308
# Prediction = Label
# Misclassified:  0
# Input: [-0.1653904   0.11737966], Label: [1], Prediction: [1], Count: 309
# Prediction = Label
# Misclassified:  0
# Input: [-0.71922612 -0.60379702], Label: [0], Prediction: [0], Count: 310
# Prediction = Label
# Misclassified:  0
# Input: [0.60148914 0.93652315], Label: [1], Prediction: [1], Count: 311
# Prediction = Label
# Misclassified:  0
# Input: [-0.37315164  0.38464523], Label: [1], Prediction: [1], Count: 312
# Prediction = Label
# Misclassified:  0
# Input: [0.7527783  0.78921333], Label: [1], Prediction: [1], Count: 313
# Prediction = Label
# Misclassified:  0
# Input: [-0.82991158 -0.92189043], Label: [0], Prediction: [0], Count: 314
# Prediction = Label
# Misclassified:  0
# Input: [-0.66033916  0.75628501], Label: [1], Prediction: [1], Count: 315
# Prediction = Label
# Misclassified:  0
# Input: [-0.80330633 -0.15778475], Label: [1], Prediction: [0], Count: 316
# Misclassified:  1
# Input: [0.91577906 0.06633057], Label: [1], Prediction: [1], Count: 317
# Prediction = Label
# Misclassified:  1
# Input: [ 0.38375423 -0.36896874], Label: [0], Prediction: [1], Count: 318
# Misclassified:  2
# Input: [0.37300186 0.66925134], Label: [1], Prediction: [1], Count: 319
# Prediction = Label
# Misclassified:  2
# Input: [-0.96342345  0.50028863], Label: [1], Prediction: [1], Count: 320
# Prediction = Label
# Misclassified:  2
# Input: [0.97772218 0.49633131], Label: [1], Prediction: [1], Count: 321
# Prediction = Label
# Misclassified:  2
# Input: [-0.43911202  0.57855866], Label: [1], Prediction: [1], Count: 322
# Prediction = Label
# Misclassified:  2
# Input: [-0.79354799 -0.10421295], Label: [1], Prediction: [1], Count: 323
# Prediction = Label
# Misclassified:  2
# Input: [ 0.81719101 -0.4127717 ], Label: [0], Prediction: [0], Count: 324
# Prediction = Label
# Misclassified:  2
# Input: [-0.42444932 -0.73994286], Label: [0], Prediction: [0], Count: 325
# Prediction = Label
# Misclassified:  2
# Input: [-0.96126608  0.35767107], Label: [1], Prediction: [1], Count: 326
# Prediction = Label
# Misclassified:  2
# Input: [-0.57674377 -0.46890668], Label: [0], Prediction: [0], Count: 327
# Prediction = Label
# Misclassified:  2
# Input: [-0.01685368 -0.89327491], Label: [0], Prediction: [0], Count: 328
# Prediction = Label
# Misclassified:  2
# Input: [ 0.14823521 -0.70654285], Label: [0], Prediction: [0], Count: 329
# Prediction = Label
# Misclassified:  2
# Input: [0.17861107 0.39951672], Label: [1], Prediction: [1], Count: 330
# Prediction = Label
# Misclassified:  2
# Input: [-0.79533114 -0.17188802], Label: [0], Prediction: [1], Count: 331
# Misclassified:  3
# Input: [ 0.38880032 -0.17164146], Label: [1], Prediction: [0], Count: 332
# Misclassified:  4
# Input: [-0.90009308  0.07179281], Label: [1], Prediction: [1], Count: 333
# Prediction = Label
# Misclassified:  4
# Input: [0.32758929 0.02977822], Label: [1], Prediction: [1], Count: 334
# Prediction = Label
# Misclassified:  4
# Input: [0.88918951 0.17311008], Label: [1], Prediction: [1], Count: 335
# Prediction = Label
# Misclassified:  4
# Input: [ 0.80680383 -0.72505059], Label: [0], Prediction: [0], Count: 336
# Prediction = Label
# Misclassified:  4
# Input: [-0.72144731  0.61478258], Label: [1], Prediction: [1], Count: 337
# Prediction = Label
# Misclassified:  4
# Input: [-0.20464633 -0.66929161], Label: [0], Prediction: [0], Count: 338
# Prediction = Label
# Misclassified:  4
# Input: [ 0.85501716 -0.30446828], Label: [1], Prediction: [1], Count: 339
# Prediction = Label
# Misclassified:  4
# Input: [0.50162421 0.45199597], Label: [1], Prediction: [1], Count: 340
# Prediction = Label
# Misclassified:  4
# Input: [0.76661218 0.24734441], Label: [1], Prediction: [1], Count: 341
# Prediction = Label
# Misclassified:  4
# Input: [ 0.50188487 -0.30220332], Label: [1], Prediction: [1], Count: 342
# Prediction = Label
# Misclassified:  4
# Input: [-0.46014422  0.79177244], Label: [1], Prediction: [1], Count: 343
# Prediction = Label
# Misclassified:  4
# Input: [-0.14381762  0.92968009], Label: [1], Prediction: [1], Count: 344
# Prediction = Label
# Misclassified:  4
# Input: [0.326883   0.24339144], Label: [1], Prediction: [1], Count: 345
# Prediction = Label
# Misclassified:  4
# Input: [-0.77050805  0.89897852], Label: [1], Prediction: [1], Count: 346
# Prediction = Label
# Misclassified:  4
# Input: [-0.10017573  0.15677923], Label: [1], Prediction: [1], Count: 347
# Prediction = Label
# Misclassified:  4
# Input: [-0.18372639 -0.52594604], Label: [0], Prediction: [0], Count: 348
# Prediction = Label
# Misclassified:  4
# Input: [0.80675904 0.14735897], Label: [1], Prediction: [1], Count: 349
# Prediction = Label
# Misclassified:  4
# Input: [-0.99425935  0.23428983], Label: [1], Prediction: [1], Count: 350
# Prediction = Label
# Misclassified:  4
# Input: [-0.3467102  0.0541162], Label: [1], Prediction: [1], Count: 351
# Prediction = Label
# Misclassified:  4
# Input: [ 0.7718842  -0.28546048], Label: [1], Prediction: [1], Count: 352
# Prediction = Label
# Misclassified:  4
# Input: [0.8170703  0.24672023], Label: [1], Prediction: [1], Count: 353
# Prediction = Label
# Misclassified:  4
# Input: [-0.96835751  0.85887447], Label: [1], Prediction: [1], Count: 354
# Prediction = Label
# Misclassified:  4
# Input: [0.38179384 0.9946457 ], Label: [1], Prediction: [1], Count: 355
# Prediction = Label
# Misclassified:  4
# Input: [-0.65531898 -0.7257285 ], Label: [0], Prediction: [0], Count: 356
# Prediction = Label
# Misclassified:  4
# Input: [0.86519093 0.39363632], Label: [1], Prediction: [1], Count: 357
# Prediction = Label
# Misclassified:  4
# Input: [-0.86799965  0.51092611], Label: [1], Prediction: [1], Count: 358
# Prediction = Label
# Misclassified:  4
# Input: [0.50775238 0.84604907], Label: [1], Prediction: [1], Count: 359
# Prediction = Label
# Misclassified:  4
# Input: [ 0.42304952 -0.75145808], Label: [0], Prediction: [0], Count: 360
# Prediction = Label
# Misclassified:  4
# Input: [-0.96023973 -0.94757803], Label: [0], Prediction: [0], Count: 361
# Prediction = Label
# Misclassified:  4
# Input: [-0.94338702 -0.50757786], Label: [0], Prediction: [0], Count: 362
# Prediction = Label
# Misclassified:  4
# Input: [0.7200559  0.07766213], Label: [1], Prediction: [1], Count: 363
# Prediction = Label
# Misclassified:  4
# Input: [0.10564396 0.68406178], Label: [1], Prediction: [1], Count: 364
# Prediction = Label
# Misclassified:  4
# Input: [-0.75165337 -0.44163264], Label: [0], Prediction: [0], Count: 365
# Prediction = Label
# Misclassified:  4
# Input: [0.17151854 0.9391915 ], Label: [1], Prediction: [1], Count: 366
# Prediction = Label
# Misclassified:  4
# Input: [ 0.12206044 -0.96270542], Label: [0], Prediction: [0], Count: 367
# Prediction = Label
# Misclassified:  4
# Input: [ 0.60126535 -0.53405145], Label: [0], Prediction: [0], Count: 368
# Prediction = Label
# Misclassified:  4
# Input: [ 0.61421039 -0.22427871], Label: [1], Prediction: [1], Count: 369
# Prediction = Label
# Misclassified:  4
# Input: [0.72708371 0.49424329], Label: [1], Prediction: [1], Count: 370
# Prediction = Label
# Misclassified:  4
# Input: [ 0.11248047 -0.72708955], Label: [0], Prediction: [0], Count: 371
# Prediction = Label
# Misclassified:  4
# Input: [-0.88016462 -0.75731309], Label: [0], Prediction: [0], Count: 372
# Prediction = Label
# Misclassified:  4
# Input: [-0.91089624 -0.78501174], Label: [0], Prediction: [0], Count: 373
# Prediction = Label
# Misclassified:  4
# Input: [-0.54858132  0.42597796], Label: [1], Prediction: [1], Count: 374
# Prediction = Label
# Misclassified:  4
# Input: [ 0.11943396 -0.97488804], Label: [0], Prediction: [0], Count: 375
# Prediction = Label
# Misclassified:  4
# Input: [-0.85605144  0.93455266], Label: [1], Prediction: [1], Count: 376
# Prediction = Label
# Misclassified:  4
# Input: [ 0.13620092 -0.59341353], Label: [0], Prediction: [0], Count: 377
# Prediction = Label
# Misclassified:  4
# Input: [-0.49534851  0.48765171], Label: [1], Prediction: [1], Count: 378
# Prediction = Label
# Misclassified:  4
# Input: [-0.60914104  0.16271785], Label: [1], Prediction: [1], Count: 379
# Prediction = Label
# Misclassified:  4
# Input: [0.94003998 0.6936576 ], Label: [1], Prediction: [1], Count: 380
# Prediction = Label
# Misclassified:  4
# Input: [-0.52030448 -0.01246057], Label: [1], Prediction: [1], Count: 381
# Prediction = Label
# Misclassified:  4
# Input: [0.23991144 0.6579618 ], Label: [1], Prediction: [1], Count: 382
# Prediction = Label
# Misclassified:  4
# Input: [-0.68641721 -0.9628476 ], Label: [0], Prediction: [0], Count: 383
# Prediction = Label
# Misclassified:  4
# Input: [-0.85995571 -0.02730978], Label: [1], Prediction: [1], Count: 384
# Prediction = Label
# Misclassified:  4
# Input: [0.21265892 0.13770287], Label: [1], Prediction: [1], Count: 385
# Prediction = Label
# Misclassified:  4
# Input: [-0.36527518  0.97723231], Label: [1], Prediction: [1], Count: 386
# Prediction = Label
# Misclassified:  4
# Input: [ 0.15949044 -0.23971765], Label: [1], Prediction: [1], Count: 387
# Prediction = Label
# Misclassified:  4
# Input: [0.10189644 0.49066886], Label: [1], Prediction: [1], Count: 388
# Prediction = Label
# Misclassified:  4
# Input: [ 0.33846579 -0.47016088], Label: [0], Prediction: [0], Count: 389
# Prediction = Label
# Misclassified:  4
# Input: [-0.86733033 -0.2598316 ], Label: [0], Prediction: [0], Count: 390
# Prediction = Label
# Misclassified:  4
# Input: [ 0.25943501 -0.57965198], Label: [0], Prediction: [0], Count: 391
# Prediction = Label
# Misclassified:  4
# Input: [ 0.50551111 -0.86692704], Label: [0], Prediction: [0], Count: 392
# Prediction = Label
# Misclassified:  4
# Input: [-0.4793698   0.60950913], Label: [1], Prediction: [1], Count: 393
# Prediction = Label
# Misclassified:  4
# Input: [-0.61313143  0.27892176], Label: [1], Prediction: [1], Count: 394
# Prediction = Label
# Misclassified:  4
# Input: [0.04934062 0.84961594], Label: [1], Prediction: [1], Count: 395
# Prediction = Label
# Misclassified:  4
# Input: [-0.47340646 -0.86807782], Label: [0], Prediction: [0], Count: 396
# Prediction = Label
# Misclassified:  4
# Input: [0.47013193 0.54435606], Label: [1], Prediction: [1], Count: 397
# Prediction = Label
# Misclassified:  4
# Input: [0.81563171 0.86394414], Label: [1], Prediction: [1], Count: 398
# Prediction = Label
# Misclassified:  4
# Input: [-0.97209685 -0.53127583], Label: [0], Prediction: [0], Count: 399
# Prediction = Label
# Misclassified:  4
# Input: [0.23355671 0.89803264], Label: [1], Prediction: [1], Count: 400
# Prediction = Label
# Misclassified:  4
# Weights: [[0.0707831 ]
#  [0.05392597]
#  [0.29383526]], Epochs: 4
# Input: [-0.16595599  0.44064899], Label: [1], Prediction: [1], Count: 401
# Prediction = Label
# Misclassified:  0
# Input: [-0.99977125 -0.39533485], Label: [0], Prediction: [0], Count: 402
# Prediction = Label
# Misclassified:  0
# Input: [-0.70648822 -0.81532281], Label: [0], Prediction: [0], Count: 403
# Prediction = Label
# Misclassified:  0
# Input: [-0.62747958 -0.30887855], Label: [0], Prediction: [0], Count: 404
# Prediction = Label
# Misclassified:  0
# Input: [-0.20646505  0.07763347], Label: [1], Prediction: [1], Count: 405
# Prediction = Label
# Misclassified:  0
# Input: [-0.16161097  0.370439  ], Label: [1], Prediction: [1], Count: 406
# Prediction = Label
# Misclassified:  0
# Input: [-0.5910955   0.75623487], Label: [1], Prediction: [1], Count: 407
# Prediction = Label
# Misclassified:  0
# Input: [-0.94522481  0.34093502], Label: [1], Prediction: [1], Count: 408
# Prediction = Label
# Misclassified:  0
# Input: [-0.1653904   0.11737966], Label: [1], Prediction: [1], Count: 409
# Prediction = Label
# Misclassified:  0
# Input: [-0.71922612 -0.60379702], Label: [0], Prediction: [0], Count: 410
# Prediction = Label
# Misclassified:  0
# Input: [0.60148914 0.93652315], Label: [1], Prediction: [1], Count: 411
# Prediction = Label
# Misclassified:  0
# Input: [-0.37315164  0.38464523], Label: [1], Prediction: [1], Count: 412
# Prediction = Label
# Misclassified:  0
# Input: [0.7527783  0.78921333], Label: [1], Prediction: [1], Count: 413
# Prediction = Label
# Misclassified:  0
# Input: [-0.82991158 -0.92189043], Label: [0], Prediction: [0], Count: 414
# Prediction = Label
# Misclassified:  0
# Input: [-0.66033916  0.75628501], Label: [1], Prediction: [1], Count: 415
# Prediction = Label
# Misclassified:  0
# Input: [-0.80330633 -0.15778475], Label: [1], Prediction: [0], Count: 416
# Misclassified:  1
# Input: [0.91577906 0.06633057], Label: [1], Prediction: [1], Count: 417
# Prediction = Label
# Misclassified:  1
# Input: [ 0.38375423 -0.36896874], Label: [0], Prediction: [1], Count: 418
# Misclassified:  2
# Input: [0.37300186 0.66925134], Label: [1], Prediction: [1], Count: 419
# Prediction = Label
# Misclassified:  2
# Input: [-0.96342345  0.50028863], Label: [1], Prediction: [1], Count: 420
# Prediction = Label
# Misclassified:  2
# Input: [0.97772218 0.49633131], Label: [1], Prediction: [1], Count: 421
# Prediction = Label
# Misclassified:  2
# Input: [-0.43911202  0.57855866], Label: [1], Prediction: [1], Count: 422
# Prediction = Label
# Misclassified:  2
# Input: [-0.79354799 -0.10421295], Label: [1], Prediction: [1], Count: 423
# Prediction = Label
# Misclassified:  2
# Input: [ 0.81719101 -0.4127717 ], Label: [0], Prediction: [0], Count: 424
# Prediction = Label
# Misclassified:  2
# Input: [-0.42444932 -0.73994286], Label: [0], Prediction: [0], Count: 425
# Prediction = Label
# Misclassified:  2
# Input: [-0.96126608  0.35767107], Label: [1], Prediction: [1], Count: 426
# Prediction = Label
# Misclassified:  2
# Input: [-0.57674377 -0.46890668], Label: [0], Prediction: [0], Count: 427
# Prediction = Label
# Misclassified:  2
# Input: [-0.01685368 -0.89327491], Label: [0], Prediction: [0], Count: 428
# Prediction = Label
# Misclassified:  2
# Input: [ 0.14823521 -0.70654285], Label: [0], Prediction: [0], Count: 429
# Prediction = Label
# Misclassified:  2
# Input: [0.17861107 0.39951672], Label: [1], Prediction: [1], Count: 430
# Prediction = Label
# Misclassified:  2
# Input: [-0.79533114 -0.17188802], Label: [0], Prediction: [1], Count: 431
# Misclassified:  3
# Input: [ 0.38880032 -0.17164146], Label: [1], Prediction: [0], Count: 432
# Misclassified:  4
# Input: [-0.90009308  0.07179281], Label: [1], Prediction: [1], Count: 433
# Prediction = Label
# Misclassified:  4
# Input: [0.32758929 0.02977822], Label: [1], Prediction: [1], Count: 434
# Prediction = Label
# Misclassified:  4
# Input: [0.88918951 0.17311008], Label: [1], Prediction: [1], Count: 435
# Prediction = Label
# Misclassified:  4
# Input: [ 0.80680383 -0.72505059], Label: [0], Prediction: [0], Count: 436
# Prediction = Label
# Misclassified:  4
# Input: [-0.72144731  0.61478258], Label: [1], Prediction: [1], Count: 437
# Prediction = Label
# Misclassified:  4
# ...
# Prediction = Label
# Misclassified:  2
# Input: [0.50775238 0.84604907], Label: [1], Prediction: [1], Count: 1159
# Prediction = Label
# Misclassified:  2
# Input: [ 0.42304952 -0.75145808], Label: [0], Prediction: [0], Count: 1160
# Prediction = Label
# Misclassified:  2
# Input: [-0.96023973 -0.94757803], Label: [0], Prediction: [0], Count: 1161
# Prediction = Label
# Misclassified:  2
# Input: [-0.94338702 -0.50757786], Label: [0], Prediction: [0], Count: 1162
# Prediction = Label
# Misclassified:  2
# Input: [0.7200559  0.07766213], Label: [1], Prediction: [1], Count: 1163
# Prediction = Label
# Misclassified:  2
# Input: [0.10564396 0.68406178], Label: [1], Prediction: [1], Count: 1164
# Prediction = Label
# Misclassified:  2
# Input: [-0.75165337 -0.44163264], Label: [0], Prediction: [0], Count: 1165
# Prediction = Label
# Misclassified:  2
# Input: [0.17151854 0.9391915 ], Label: [1], Prediction: [1], Count: 1166
# Prediction = Label
# Misclassified:  2
# Input: [ 0.12206044 -0.96270542], Label: [0], Prediction: [0], Count: 1167
# Prediction = Label
# Misclassified:  2
# Input: [ 0.60126535 -0.53405145], Label: [0], Prediction: [0], Count: 1168
# Prediction = Label
# Misclassified:  2
# Input: [ 0.61421039 -0.22427871], Label: [1], Prediction: [1], Count: 1169
# Prediction = Label
# Misclassified:  2
# Input: [0.72708371 0.49424329], Label: [1], Prediction: [1], Count: 1170
# Prediction = Label
# Misclassified:  2
# Input: [ 0.11248047 -0.72708955], Label: [0], Prediction: [0], Count: 1171
# Prediction = Label
# Misclassified:  2
# Input: [-0.88016462 -0.75731309], Label: [0], Prediction: [0], Count: 1172
# Prediction = Label
# Misclassified:  2
# Input: [-0.91089624 -0.78501174], Label: [0], Prediction: [0], Count: 1173
# Prediction = Label
# Misclassified:  2
# Input: [-0.54858132  0.42597796], Label: [1], Prediction: [1], Count: 1174
# Prediction = Label
# Misclassified:  2
# Input: [ 0.11943396 -0.97488804], Label: [0], Prediction: [0], Count: 1175
# Prediction = Label
# Misclassified:  2
# Input: [-0.85605144  0.93455266], Label: [1], Prediction: [1], Count: 1176
# Prediction = Label
# Misclassified:  2
# Input: [ 0.13620092 -0.59341353], Label: [0], Prediction: [0], Count: 1177
# Prediction = Label
# Misclassified:  2
# Input: [-0.49534851  0.48765171], Label: [1], Prediction: [1], Count: 1178
# Prediction = Label
# Misclassified:  2
# Input: [-0.60914104  0.16271785], Label: [1], Prediction: [1], Count: 1179
# Prediction = Label
# Misclassified:  2
# Input: [0.94003998 0.6936576 ], Label: [1], Prediction: [1], Count: 1180
# Prediction = Label
# Misclassified:  2
# Input: [-0.52030448 -0.01246057], Label: [1], Prediction: [1], Count: 1181
# Prediction = Label
# Misclassified:  2
# Input: [0.23991144 0.6579618 ], Label: [1], Prediction: [1], Count: 1182
# Prediction = Label
# Misclassified:  2
# Input: [-0.68641721 -0.9628476 ], Label: [0], Prediction: [0], Count: 1183
# Prediction = Label
# Misclassified:  2
# Input: [-0.85995571 -0.02730978], Label: [1], Prediction: [0], Count: 1184
# Misclassified:  3
# Input: [0.21265892 0.13770287], Label: [1], Prediction: [1], Count: 1185
# Prediction = Label
# Misclassified:  3
# Input: [-0.36527518  0.97723231], Label: [1], Prediction: [1], Count: 1186
# Prediction = Label
# Misclassified:  3
# Input: [ 0.15949044 -0.23971765], Label: [1], Prediction: [1], Count: 1187
# Prediction = Label
# Misclassified:  3
# Input: [0.10189644 0.49066886], Label: [1], Prediction: [1], Count: 1188
# Prediction = Label
# Misclassified:  3
# Input: [ 0.33846579 -0.47016088], Label: [0], Prediction: [1], Count: 1189
# Misclassified:  4
# Input: [-0.86733033 -0.2598316 ], Label: [0], Prediction: [0], Count: 1190
# Prediction = Label
# Misclassified:  4
# Input: [ 0.25943501 -0.57965198], Label: [0], Prediction: [0], Count: 1191
# Prediction = Label
# Misclassified:  4
# Input: [ 0.50551111 -0.86692704], Label: [0], Prediction: [0], Count: 1192
# Prediction = Label
# Misclassified:  4
# Input: [-0.4793698   0.60950913], Label: [1], Prediction: [1], Count: 1193
# Prediction = Label
# Misclassified:  4
# Input: [-0.61313143  0.27892176], Label: [1], Prediction: [1], Count: 1194
# Prediction = Label
# Misclassified:  4
# Input: [0.04934062 0.84961594], Label: [1], Prediction: [1], Count: 1195
# Prediction = Label
# Misclassified:  4
# Input: [-0.47340646 -0.86807782], Label: [0], Prediction: [0], Count: 1196
# Prediction = Label
# Misclassified:  4
# Input: [0.47013193 0.54435606], Label: [1], Prediction: [1], Count: 1197
# Prediction = Label
# Misclassified:  4
# Input: [0.81563171 0.86394414], Label: [1], Prediction: [1], Count: 1198
# Prediction = Label
# Misclassified:  4
# Input: [-0.97209685 -0.53127583], Label: [0], Prediction: [0], Count: 1199
# Prediction = Label
# Misclassified:  4
# Input: [0.23355671 0.89803264], Label: [1], Prediction: [1], Count: 1200
# Prediction = Label
# Misclassified:  4
# Weights: [[0.1707831 ]
#  [0.08150437]
#  [0.61957455]], Epochs: 12
# Input: [-0.16595599  0.44064899], Label: [1], Prediction: [1], Count: 1201
# Prediction = Label
# Misclassified:  0
# Input: [-0.99977125 -0.39533485], Label: [0], Prediction: [0], Count: 1202
# Prediction = Label
# Misclassified:  0
# Input: [-0.70648822 -0.81532281], Label: [0], Prediction: [0], Count: 1203
# Prediction = Label
# Misclassified:  0
# Input: [-0.62747958 -0.30887855], Label: [0], Prediction: [0], Count: 1204
# Prediction = Label
# Misclassified:  0
# Input: [-0.20646505  0.07763347], Label: [1], Prediction: [1], Count: 1205
# Prediction = Label
# Misclassified:  0
# Input: [-0.16161097  0.370439  ], Label: [1], Prediction: [1], Count: 1206
# Prediction = Label
# Misclassified:  0
# Input: [-0.5910955   0.75623487], Label: [1], Prediction: [1], Count: 1207
# Prediction = Label
# Misclassified:  0
# Input: [-0.94522481  0.34093502], Label: [1], Prediction: [1], Count: 1208
# Prediction = Label
# Misclassified:  0
# Input: [-0.1653904   0.11737966], Label: [1], Prediction: [1], Count: 1209
# Prediction = Label
# Misclassified:  0
# Input: [-0.71922612 -0.60379702], Label: [0], Prediction: [0], Count: 1210
# Prediction = Label
# Misclassified:  0
# Input: [0.60148914 0.93652315], Label: [1], Prediction: [1], Count: 1211
# Prediction = Label
# Misclassified:  0
# Input: [-0.37315164  0.38464523], Label: [1], Prediction: [1], Count: 1212
# Prediction = Label
# Misclassified:  0
# Input: [0.7527783  0.78921333], Label: [1], Prediction: [1], Count: 1213
# Prediction = Label
# Misclassified:  0
# Input: [-0.82991158 -0.92189043], Label: [0], Prediction: [0], Count: 1214
# Prediction = Label
# Misclassified:  0
# Input: [-0.66033916  0.75628501], Label: [1], Prediction: [1], Count: 1215
# Prediction = Label
# Misclassified:  0
# Input: [-0.80330633 -0.15778475], Label: [1], Prediction: [1], Count: 1216
# Prediction = Label
# Misclassified:  0
# Input: [0.91577906 0.06633057], Label: [1], Prediction: [1], Count: 1217
# Prediction = Label
# Misclassified:  0
# Input: [ 0.38375423 -0.36896874], Label: [0], Prediction: [0], Count: 1218
# Prediction = Label
# Misclassified:  0
# Input: [0.37300186 0.66925134], Label: [1], Prediction: [1], Count: 1219
# Prediction = Label
# Misclassified:  0
# Input: [-0.96342345  0.50028863], Label: [1], Prediction: [1], Count: 1220
# Prediction = Label
# Misclassified:  0
# Input: [0.97772218 0.49633131], Label: [1], Prediction: [1], Count: 1221
# Prediction = Label
# Misclassified:  0
# Input: [-0.43911202  0.57855866], Label: [1], Prediction: [1], Count: 1222
# Prediction = Label
# Misclassified:  0
# Input: [-0.79354799 -0.10421295], Label: [1], Prediction: [1], Count: 1223
# Prediction = Label
# Misclassified:  0
# Input: [ 0.81719101 -0.4127717 ], Label: [0], Prediction: [0], Count: 1224
# Prediction = Label
# Misclassified:  0
# Input: [-0.42444932 -0.73994286], Label: [0], Prediction: [0], Count: 1225
# Prediction = Label
# Misclassified:  0
# Input: [-0.96126608  0.35767107], Label: [1], Prediction: [1], Count: 1226
# Prediction = Label
# Misclassified:  0
# Input: [-0.57674377 -0.46890668], Label: [0], Prediction: [0], Count: 1227
# Prediction = Label
# Misclassified:  0
# Input: [-0.01685368 -0.89327491], Label: [0], Prediction: [0], Count: 1228
# Prediction = Label
# Misclassified:  0
# Input: [ 0.14823521 -0.70654285], Label: [0], Prediction: [0], Count: 1229
# Prediction = Label
# Misclassified:  0
# Input: [0.17861107 0.39951672], Label: [1], Prediction: [1], Count: 1230
# Prediction = Label
# Misclassified:  0
# Input: [-0.79533114 -0.17188802], Label: [0], Prediction: [0], Count: 1231
# Prediction = Label
# Misclassified:  0
# Input: [ 0.38880032 -0.17164146], Label: [1], Prediction: [1], Count: 1232
# Prediction = Label
# Misclassified:  0
# Input: [-0.90009308  0.07179281], Label: [1], Prediction: [1], Count: 1233
# Prediction = Label
# Misclassified:  0
# Input: [0.32758929 0.02977822], Label: [1], Prediction: [1], Count: 1234
# Prediction = Label
# Misclassified:  0
# Input: [0.88918951 0.17311008], Label: [1], Prediction: [1], Count: 1235
# Prediction = Label
# Misclassified:  0
# Input: [ 0.80680383 -0.72505059], Label: [0], Prediction: [0], Count: 1236
# Prediction = Label
# Misclassified:  0
# Input: [-0.72144731  0.61478258], Label: [1], Prediction: [1], Count: 1237
# Prediction = Label
# Misclassified:  0
# Input: [-0.20464633 -0.66929161], Label: [0], Prediction: [0], Count: 1238
# Prediction = Label
# Misclassified:  0
# Input: [ 0.85501716 -0.30446828], Label: [1], Prediction: [1], Count: 1239
# Prediction = Label
# Misclassified:  0
# Input: [0.50162421 0.45199597], Label: [1], Prediction: [1], Count: 1240
# Prediction = Label
# Misclassified:  0
# Input: [0.76661218 0.24734441], Label: [1], Prediction: [1], Count: 1241
# Prediction = Label
# Misclassified:  0
# Input: [ 0.50188487 -0.30220332], Label: [1], Prediction: [1], Count: 1242
# Prediction = Label
# Misclassified:  0
# Input: [-0.46014422  0.79177244], Label: [1], Prediction: [1], Count: 1243
# Prediction = Label
# Misclassified:  0
# Input: [-0.14381762  0.92968009], Label: [1], Prediction: [1], Count: 1244
# Prediction = Label
# Misclassified:  0
# Input: [0.326883   0.24339144], Label: [1], Prediction: [1], Count: 1245
# Prediction = Label
# Misclassified:  0
# Input: [-0.77050805  0.89897852], Label: [1], Prediction: [1], Count: 1246
# Prediction = Label
# Misclassified:  0
# Input: [-0.10017573  0.15677923], Label: [1], Prediction: [1], Count: 1247
# Prediction = Label
# Misclassified:  0
# Input: [-0.18372639 -0.52594604], Label: [0], Prediction: [0], Count: 1248
# Prediction = Label
# Misclassified:  0
# Input: [0.80675904 0.14735897], Label: [1], Prediction: [1], Count: 1249
# Prediction = Label
# Misclassified:  0
# Input: [-0.99425935  0.23428983], Label: [1], Prediction: [1], Count: 1250
# Prediction = Label
# Misclassified:  0
# Input: [-0.3467102  0.0541162], Label: [1], Prediction: [1], Count: 1251
# Prediction = Label
# Misclassified:  0
# Input: [ 0.7718842  -0.28546048], Label: [1], Prediction: [1], Count: 1252
# Prediction = Label
# Misclassified:  0
# Input: [0.8170703  0.24672023], Label: [1], Prediction: [1], Count: 1253
# Prediction = Label
# Misclassified:  0
# Input: [-0.96835751  0.85887447], Label: [1], Prediction: [1], Count: 1254
# Prediction = Label
# Misclassified:  0
# Input: [0.38179384 0.9946457 ], Label: [1], Prediction: [1], Count: 1255
# Prediction = Label
# Misclassified:  0
# Input: [-0.65531898 -0.7257285 ], Label: [0], Prediction: [0], Count: 1256
# Prediction = Label
# Misclassified:  0
# Input: [0.86519093 0.39363632], Label: [1], Prediction: [1], Count: 1257
# Prediction = Label
# Misclassified:  0
# Input: [-0.86799965  0.51092611], Label: [1], Prediction: [1], Count: 1258
# Prediction = Label
# Misclassified:  0
# Input: [0.50775238 0.84604907], Label: [1], Prediction: [1], Count: 1259
# Prediction = Label
# Misclassified:  0
# Input: [ 0.42304952 -0.75145808], Label: [0], Prediction: [0], Count: 1260
# Prediction = Label
# Misclassified:  0
# Input: [-0.96023973 -0.94757803], Label: [0], Prediction: [0], Count: 1261
# Prediction = Label
# Misclassified:  0
# Input: [-0.94338702 -0.50757786], Label: [0], Prediction: [0], Count: 1262
# Prediction = Label
# Misclassified:  0
# Input: [0.7200559  0.07766213], Label: [1], Prediction: [1], Count: 1263
# Prediction = Label
# Misclassified:  0
# Input: [0.10564396 0.68406178], Label: [1], Prediction: [1], Count: 1264
# Prediction = Label
# Misclassified:  0
# Input: [-0.75165337 -0.44163264], Label: [0], Prediction: [0], Count: 1265
# Prediction = Label
# Misclassified:  0
# Input: [0.17151854 0.9391915 ], Label: [1], Prediction: [1], Count: 1266
# Prediction = Label
# Misclassified:  0
# Input: [ 0.12206044 -0.96270542], Label: [0], Prediction: [0], Count: 1267
# Prediction = Label
# Misclassified:  0
# Input: [ 0.60126535 -0.53405145], Label: [0], Prediction: [0], Count: 1268
# Prediction = Label
# Misclassified:  0
# Input: [ 0.61421039 -0.22427871], Label: [1], Prediction: [1], Count: 1269
# Prediction = Label
# Misclassified:  0
# Input: [0.72708371 0.49424329], Label: [1], Prediction: [1], Count: 1270
# Prediction = Label
# Misclassified:  0
# Input: [ 0.11248047 -0.72708955], Label: [0], Prediction: [0], Count: 1271
# Prediction = Label
# Misclassified:  0
# Input: [-0.88016462 -0.75731309], Label: [0], Prediction: [0], Count: 1272
# Prediction = Label
# Misclassified:  0
# Input: [-0.91089624 -0.78501174], Label: [0], Prediction: [0], Count: 1273
# Prediction = Label
# Misclassified:  0
# Input: [-0.54858132  0.42597796], Label: [1], Prediction: [1], Count: 1274
# Prediction = Label
# Misclassified:  0
# Input: [ 0.11943396 -0.97488804], Label: [0], Prediction: [0], Count: 1275
# Prediction = Label
# Misclassified:  0
# Input: [-0.85605144  0.93455266], Label: [1], Prediction: [1], Count: 1276
# Prediction = Label
# Misclassified:  0
# Input: [ 0.13620092 -0.59341353], Label: [0], Prediction: [0], Count: 1277
# Prediction = Label
# Misclassified:  0
# Input: [-0.49534851  0.48765171], Label: [1], Prediction: [1], Count: 1278
# Prediction = Label
# Misclassified:  0
# Input: [-0.60914104  0.16271785], Label: [1], Prediction: [1], Count: 1279
# Prediction = Label
# Misclassified:  0
# Input: [0.94003998 0.6936576 ], Label: [1], Prediction: [1], Count: 1280
# Prediction = Label
# Misclassified:  0
# Input: [-0.52030448 -0.01246057], Label: [1], Prediction: [1], Count: 1281
# Prediction = Label
# Misclassified:  0
# Input: [0.23991144 0.6579618 ], Label: [1], Prediction: [1], Count: 1282
# Prediction = Label
# Misclassified:  0
# Input: [-0.68641721 -0.9628476 ], Label: [0], Prediction: [0], Count: 1283
# Prediction = Label
# Misclassified:  0
# Input: [-0.85995571 -0.02730978], Label: [1], Prediction: [1], Count: 1284
# Prediction = Label
# Misclassified:  0
# Input: [0.21265892 0.13770287], Label: [1], Prediction: [1], Count: 1285
# Prediction = Label
# Misclassified:  0
# Input: [-0.36527518  0.97723231], Label: [1], Prediction: [1], Count: 1286
# Prediction = Label
# Misclassified:  0
# Input: [ 0.15949044 -0.23971765], Label: [1], Prediction: [1], Count: 1287
# Prediction = Label
# Misclassified:  0
# Input: [0.10189644 0.49066886], Label: [1], Prediction: [1], Count: 1288
# Prediction = Label
# Misclassified:  0
# Input: [ 0.33846579 -0.47016088], Label: [0], Prediction: [0], Count: 1289
# Prediction = Label
# Misclassified:  0
# Input: [-0.86733033 -0.2598316 ], Label: [0], Prediction: [0], Count: 1290
# Prediction = Label
# Misclassified:  0
# Input: [ 0.25943501 -0.57965198], Label: [0], Prediction: [0], Count: 1291
# Prediction = Label
# Misclassified:  0
# Input: [ 0.50551111 -0.86692704], Label: [0], Prediction: [0], Count: 1292
# Prediction = Label
# Misclassified:  0
# Input: [-0.4793698   0.60950913], Label: [1], Prediction: [1], Count: 1293
# Prediction = Label
# Misclassified:  0
# Input: [-0.61313143  0.27892176], Label: [1], Prediction: [1], Count: 1294
# Prediction = Label
# Misclassified:  0
# Input: [0.04934062 0.84961594], Label: [1], Prediction: [1], Count: 1295
# Prediction = Label
# Misclassified:  0
# Input: [-0.47340646 -0.86807782], Label: [0], Prediction: [0], Count: 1296
# Prediction = Label
# Misclassified:  0
# Input: [0.47013193 0.54435606], Label: [1], Prediction: [1], Count: 1297
# Prediction = Label
# Misclassified:  0
# Input: [0.81563171 0.86394414], Label: [1], Prediction: [1], Count: 1298
# Prediction = Label
# Misclassified:  0
# Input: [-0.97209685 -0.53127583], Label: [0], Prediction: [0], Count: 1299
# Prediction = Label
# Misclassified:  0
# Input: [0.23355671 0.89803264], Label: [1], Prediction: [1], Count: 1300
# Prediction = Label
# Misclassified:  0
# Weights: [[0.1707831 ]
#  [0.08150437]
#  [0.61957455]], Epochs: 13
# [10, 4, 4, 4, 4, 8, 8, 5, 7, 5, 2, 4, 0]

# %%
epochs = np.arange(1, perceptron.epochs+1)
plt.plot(epochs, perceptron.misclassified_list)
plt.xlabel('Epochs')
plt.ylabel('Misclassified')
plt.show()
